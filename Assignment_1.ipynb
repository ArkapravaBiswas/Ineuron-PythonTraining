# %%
""" 2.
Write a program which will find all such numbers which are divisible by 7 but are not a multiple
of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
comma-separated sequence on a single line."""


result_list=[]
for number in range(2000,3201):
    if ((number%7==0) and (number%5!=0)):
        result_list.append(number)
for final_number in result_list:
    print(final_number,end=',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %%
"""3.
Write a Python program to accept the user's first and last name and then getting them printed in
the the reverse order with a space between first name and last name."""

input_list=[]
output_list=[]
formatted_output=''
input_list.append(input('enter the first name: '))
input_list.append(input('enter the second number: '))
input_list.reverse()
for i in input_list:
    output_list.append(i[::-1])
print(output_list)
for i in output_list:
    formatted_output=formatted_output+i+" "
print("the required output: ",formatted_output)
# Out:
# enter the first name:  arkaprava
# enter the second number:  biswas
# ['sawsib', 'avarpakra']
# the required output:  sawsib avarpakra

# %%
"""4.
Write a Python program to find the volume of a sphere with diameter 12 cm.
Formula: V=4/3 * π * r 3 """


diameter=12
radius=diameter/2
volume=4/3*3.14*(radius**3)
print("the required volume: ",volume)
# Out:
# the required volume:  904.3199999999999

# %%
"""Task 2:
1.
Write a program which accepts a sequence of comma-separated numbers from console and
generate a list."""


# 1st way where user himself enters with the comma
#Input_string=(input("Enter the numbers with a comma in between: ")).split(',')
#print("The required output: ",Input_string)

#2nd way where the user simply enters the number one by one (ouput is diplayed for this case)
no=""
input_list=[]
total_no_of_inputs=int(input("Enter the total number of inputs"))
for r in range(total_no_of_inputs):
    no=(input("entre the number one by one: "))
    input_list.append(no)
print("The required list: ",input_list)
# Out:
# Enter the total number of inputs 3
# entre the number one by one:  1
# entre the number one by one:  2
# entre the number one by one:  3
# The required list:  ['1', '2', '3']

# %%
"""2.
Create the below pattern using nested for loop in Python.
*
* *
* * *
* * * *
* * * * *
* * * *
* * *
* *
*"""

number_of_rows=5;
for i in range(number_of_rows):
    for j in range(i):
        print ('* ', end="")
    print('')

for i in range(number_of_rows,0,-1):
    for j in range(i):
        print('* ', end="")
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
"""3.
Write a Python program to reverse a word after accepting the input from the user.
Sample Output:
Input word: AcadGild
Output: dilGdacA"""

Input_string=input("enter the string")
Output_string=Input_string[::-1]
print("the required output: ",Output_string)
# Out:
# enter the string AcadGild
# the required output:  dliGdacA

# %%
"""4.
Write a Python Program to print the given string in the format specified in the sample output.
WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
its citizens
Sample Output:
WE, THE PEOPLE OF INDIA,
having solemnly resolved to constitute India into a SOVEREIGN, !
SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
and to secure to all its citizens"""


input_string = "WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens"
print ("input_sentence : " + input_string+'\n')

ouput_string = input_string.replace("INDIA, ", "INDIA,\n").replace("SOVEREIGN, ", "SOVEREIGN, !\n").replace("REPUBLIC ", "REPUBLIC \n") + (":")
print ("The required output : " + ouput_string)
# Out:
# input_sentence : WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
#
# The required output : WE, THE PEOPLE OF INDIA,
# having solemnly resolved to constitute India into a SOVEREIGN, !
# SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# and to secure to all its citizens:
